# %%
# ============================================================
# PHAT HIEN BAT THUONG REALTIME
# Deep Autoencoder + LSTM Autoencoder
# FINAL VERSION FOR THESIS
# ============================================================

import threading
import queue
import time
import joblib
import psutil

import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder


def load_model_compatible(model_path, compile=False):
    """
    Load .h5 model safely across Keras versions.
    Some saved .h5 files contain quantization_config in Dense layers,
    while older TensorFlow/Keras versions do not understand that field.
    """

    try:
        return load_model(
            model_path,
            compile=compile
        )

    except Exception as first_error:
        if "quantization_config" not in str(first_error):
            raise

        print(
            f"[INFO] Dang nap lai {model_path} voi che do tuong thich Keras..."
        )

        original_dense_from_config = Dense.from_config

        def dense_from_config_compatible(cls, config):
            config = dict(config)
            config.pop("quantization_config", None)
            return original_dense_from_config(config)

        Dense.from_config = classmethod(dense_from_config_compatible)

        try:
            return load_model(
                model_path,
                compile=compile
            )
        finally:
            Dense.from_config = original_dense_from_config

print("\n====================================================")
print("HE THONG GIAM SAT THOI GIAN THUC")
print("Deep Autoencoder + LSTM Autoencoder")
print("====================================================")


# ============================================================
# FILE LOG
# ============================================================

log_file = open(
    "system_alert_log.txt",
    "w",
    encoding="utf-8"
)


# ============================================================
# LOAD MODEL + SCALER
# ============================================================

print("\n[1] DANG NAP MODEL...")


try:

    traffic_model = load_model_compatible(
        "./models/deep_autoencoder_traffic.h5",
        compile=False
    )

    log_model = load_model_compatible(
        "./models/lstm_autoencoder_logs.h5",
        compile=False
    )

    traffic_scaler = joblib.load(
        "./models/traffic_scaler.pkl"
    )

    log_scaler = joblib.load(
        "./models/log_scaler.pkl"
    )

    print("[OK] Traffic Model Loaded")
    print("[OK] Log Model Loaded")
    print("[OK] Traffic Scaler Loaded")
    print("[OK] Log Scaler Loaded")

except Exception as e:

    print("\n[LOI] KHONG NAP DUOC MODEL")
    print(e)

    raise SystemExit()


# ============================================================
# 47 FEATURE TRAFFIC
# PHAI GIU DUNG THU TU LUC TRAIN
# ============================================================

TRAFFIC_FEATURES = [

    'Flow Duration',

    'Total Fwd Packets',
    'Total Backward Packets',

    'Total Length of Fwd Packets',
    'Total Length of Bwd Packets',

    'Fwd Packet Length Max',
    'Fwd Packet Length Min',
    'Fwd Packet Length Mean',
    'Fwd Packet Length Std',

    'Bwd Packet Length Max',
    'Bwd Packet Length Min',
    'Bwd Packet Length Mean',
    'Bwd Packet Length Std',

    'Flow Bytes/s',
    'Flow Packets/s',

    'Flow IAT Mean',
    'Flow IAT Std',
    'Flow IAT Max',
    'Flow IAT Min',

    'Fwd IAT Total',
    'Fwd IAT Mean',
    'Fwd IAT Std',
    'Fwd IAT Max',
    'Fwd IAT Min',

    'Bwd IAT Total',
    'Bwd IAT Mean',
    'Bwd IAT Std',
    'Bwd IAT Max',
    'Bwd IAT Min',

    'Fwd PSH Flags',

    'Fwd Header Length',
    'Bwd Header Length',

    'Fwd Packets/s',
    'Bwd Packets/s',

    'Min Packet Length',
    'Max Packet Length',

    'Packet Length Mean',
    'Packet Length Std',
    'Packet Length Variance',

    'FIN Flag Count',
    'SYN Flag Count',
    'RST Flag Count',
    'PSH Flag Count',
    'ACK Flag Count',
    'URG Flag Count',

    'Average Packet Size',
    'Avg Bwd Segment Size'
]


print(
    f"[OK] Traffic Feature Count = {len(TRAFFIC_FEATURES)}"
)


# ============================================================
# QUEUE
# ============================================================

traffic_queue = queue.Queue(maxsize=500)

log_queue = queue.Queue(maxsize=500)


# ============================================================
# BIEN THONG KE
# ============================================================

traffic_alert_count = 0
log_alert_count = 0

traffic_total_count = 0
log_total_count = 0

latency_history = []

peak_ram_mb = 0

system_running = True
# ============================================================
# PHAN 2/6: DOC VA XU LY DU LIEU NETWORK TRAFFIC
# ============================================================

print("\n[2] DANG DOC VA XU LY NETWORK TRAFFIC...")


# ============================================================
# CAU HINH DATASET DEMO
# ============================================================

TRAFFIC_CSV_PATH = (
    "./dataset/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv"
)

NUM_BENIGN_CALIB = 100       # Dung de tinh dynamic threshold
NUM_ATTACK_DEMO = 1900       # Dung de demo tan cong DDoS


# ============================================================
# HAM TIEN XU LY TRAFFIC
# ============================================================

def preprocess_traffic_dataframe(df_input):
    """
    Tien xu ly traffic dung chuan voi model FINAL V3:
    - Strip ten cot
    - Lay dung 47 feature
    - Xu ly inf, nan
    - Clip theo min/max cua scaler da train
    - Transform bang traffic_scaler.pkl
    """

    df = df_input.copy()

    df.columns = df.columns.str.strip()

    missing_cols = [
        col for col in TRAFFIC_FEATURES
        if col not in df.columns
    ]

    if len(missing_cols) > 0:
        raise ValueError(
            f"Thieu cot traffic: {missing_cols}"
        )

    X = df[TRAFFIC_FEATURES].copy()

    # Xu ly inf / nan
    X.replace(
        [np.inf, -np.inf],
        np.nan,
        inplace=True
    )

    X.fillna(
        0,
        inplace=True
    )

    # --------------------------------------------------------
    # QUAN TRONG:
    # Khong fit scaler moi.
    # Clip theo data_min_ va data_max_ cua scaler da train.
    # Day la bien the tuong duong voi viec du lieu train da cat outlier
    # truoc khi fit MinMaxScaler.
    # --------------------------------------------------------

    train_min = traffic_scaler.data_min_

    train_max = traffic_scaler.data_max_

    X_values = X.values.astype(float)

    X_values = np.clip(
        X_values,
        train_min,
        train_max
    )

    X_scaled = traffic_scaler.transform(
        X_values
    )

    return X_scaled


# ============================================================
# DOC FILE TRAFFIC
# ============================================================

try:

    df_traffic_full = pd.read_csv(
        TRAFFIC_CSV_PATH
    )

    df_traffic_full.columns = (
        df_traffic_full.columns.str.strip()
    )

    if "Label" not in df_traffic_full.columns:
        raise ValueError(
            "File traffic khong co cot Label"
        )

    # --------------------------------------------------------
    # Tao kich ban demo:
    # 100 BENIGN dau tien -> calibration
    # 1900 DDoS -> monitoring anomaly
    # --------------------------------------------------------

    df_benign = (
        df_traffic_full[
            df_traffic_full["Label"] == "BENIGN"
        ]
        .head(NUM_BENIGN_CALIB)
    )

    df_attack = (
        df_traffic_full[
            df_traffic_full["Label"] != "BENIGN"
        ]
        .head(NUM_ATTACK_DEMO)
    )

    df_traffic_stream = pd.concat(
        [
            df_benign,
            df_attack
        ],
        axis=0
    ).reset_index(drop=True)

    traffic_labels = (
        df_traffic_stream["Label"]
        .values
    )

    print(
        "-> Phan bo label Traffic:",
        df_traffic_stream["Label"]
        .value_counts()
        .to_dict()
    )

    X_real_traffic = preprocess_traffic_dataframe(
        df_traffic_stream
    )

    print(
        f"-> [OK] Traffic stream shape: {X_real_traffic.shape}"
    )

    print(
        f"-> [OK] So mau calibration BENIGN: {len(df_benign)}"
    )

    print(
        f"-> [OK] So mau attack demo: {len(df_attack)}"
    )


except Exception as e:

    print("\n[LOI] Khong xu ly duoc Traffic Dataset")
    print(e)

    log_file.close()

    raise SystemExit()


# ============================================================
# KIEM TRA INPUT MODEL TRAFFIC
# ============================================================

expected_traffic_dim = traffic_model.input_shape[-1]

actual_traffic_dim = X_real_traffic.shape[1]

if expected_traffic_dim != actual_traffic_dim:

    print("\n[LOI] Sai so chieu Traffic Model")
    print(
        f"Model can: {expected_traffic_dim} feature"
    )
    print(
        f"Du lieu co: {actual_traffic_dim} feature"
    )

    log_file.close()

    raise SystemExit()

else:

    print(
        f"-> [OK] Traffic input dim hop le: {actual_traffic_dim}"
    )
    # ============================================================
# PHAN 3/6: DOC VA XU LY DU LIEU HDFS LOG
# ============================================================

print("\n[3] DANG DOC VA XU LY HDFS LOG...")


# ============================================================
# CAU HINH DATASET LOG
# ============================================================

LOG_CSV_PATH = (
    "./dataset/HDFS_2k.log_structured.csv"
)

TIMESTEPS = 10

LOG_FEATURE_DIM = 4


# ============================================================
# HAM TIEN XU LY HDFS LOG
# ============================================================

def preprocess_hdfs_log_dataframe(df_input):
    """
    Tien xu ly HDFS Log dung chuan voi LSTM Autoencoder:
    - EventId -> EventId_num
    - Level -> Level_num
    - Component -> Component_num
    - Pid -> Pid_norm
    - Scale bang log_scaler.pkl da train
    - Dong goi thanh sequence (N, 10, 4)
    """

    df = df_input.copy()

    # --------------------------------------------------------
    # Kiem tra cot can thiet
    # --------------------------------------------------------

    required_cols = [
        "EventId",
        "Level",
        "Component",
        "Pid"
    ]

    missing_cols = [
        col for col in required_cols
        if col not in df.columns
    ]

    if len(missing_cols) > 0:
        raise ValueError(
            f"Thieu cot log: {missing_cols}"
        )


    # --------------------------------------------------------
    # Feature 1: EventId -> so nguyen
    # Vi du E1 -> 1, E2 -> 2
    # --------------------------------------------------------

    df["EventId_num"] = (
        df["EventId"]
        .astype(str)
        .str.extract(r"E(\d+)")
        .astype(float)
    )


    # --------------------------------------------------------
    # Feature 2: Level -> nhi phan
    # INFO = 0, WARN = 1
    # --------------------------------------------------------

    df["Level_num"] = (
        df["Level"] == "WARN"
    ).astype(float)


    # --------------------------------------------------------
    # Feature 3: Component -> ma hoa so
    # Luu y:
    # Code train ban dau dung LabelEncoder fit tren HDFS_2k.
    # Local demo doc cung file HDFS_2k nen cach nay khop duoc.
    # Neu dung file log khac, nen luu LabelEncoder rieng.
    # --------------------------------------------------------

    le_component = LabelEncoder()

    df["Component_num"] = (
        le_component
        .fit_transform(df["Component"])
        .astype(float)
    )


    # --------------------------------------------------------
    # Feature 4: Pid normalize ve [0,1]
    # --------------------------------------------------------

    pid_min = df["Pid"].min()

    pid_max = df["Pid"].max()

    if pid_max == pid_min:
        df["Pid_norm"] = 0.0
    else:
        df["Pid_norm"] = (
            (df["Pid"] - pid_min)
            /
            (pid_max - pid_min)
        )


    # --------------------------------------------------------
    # Lay 4 feature
    # --------------------------------------------------------

    log_features = df[
        [
            "EventId_num",
            "Level_num",
            "Component_num",
            "Pid_norm"
        ]
    ].values


    # Xu ly inf / nan
    log_features = np.nan_to_num(
        log_features,
        nan=0.0,
        posinf=0.0,
        neginf=0.0
    )


    # --------------------------------------------------------
    # Scale bang scaler da train
    # Khong fit scaler moi.
    # --------------------------------------------------------

    log_features_scaled = (
        log_scaler.transform(log_features)
    )


    # --------------------------------------------------------
    # Dong goi thanh sequence 10 timestep
    # --------------------------------------------------------

    n_seq = (
        len(log_features_scaled)
        // TIMESTEPS
    )

    if n_seq == 0:
        raise ValueError(
            "Khong du log de tao sequence 10 timestep"
        )

    X_log_seq = (
        log_features_scaled[
            : n_seq * TIMESTEPS
        ]
        .reshape(
            n_seq,
            TIMESTEPS,
            LOG_FEATURE_DIM
        )
    )

    return X_log_seq, n_seq


# ============================================================
# DOC VA XU LY FILE LOG
# ============================================================

try:

    df_log_full = pd.read_csv(
        LOG_CSV_PATH,
        nrows=2000
    )

    X_log_base, n_log_seq = preprocess_hdfs_log_dataframe(
        df_log_full
    )

    # --------------------------------------------------------
    # Lap lai sequence log de khop do dai voi traffic stream
    # --------------------------------------------------------

    repeat_times = int(
        np.ceil(
            len(X_real_traffic) / len(X_log_base)
        )
    )

    X_real_log = np.tile(
        X_log_base,
        (
            repeat_times,
            1,
            1
        )
    )[:len(X_real_traffic)]

    print(
        f"-> [OK] HDFS Log base shape: {X_log_base.shape}"
    )

    print(
        f"-> [OK] HDFS Log stream shape: {X_real_log.shape}"
    )

    print(
        f"-> [OK] So sequence goc: {n_log_seq}"
    )

except Exception as e:

    print("\n[LOI] Khong xu ly duoc HDFS Log")
    print(e)

    log_file.close()

    raise SystemExit()


# ============================================================
# KIEM TRA INPUT MODEL LOG
# ============================================================

expected_log_shape = log_model.input_shape[1:]

actual_log_shape = X_real_log.shape[1:]

if expected_log_shape != actual_log_shape:

    print("\n[LOI] Sai shape Log Model")
    print(
        f"Model can: {expected_log_shape}"
    )
    print(
        f"Du lieu co: {actual_log_shape}"
    )

    log_file.close()

    raise SystemExit()

else:

    print(
        f"-> [OK] Log input shape hop le: {actual_log_shape}"
    )

# ============================================================
# PHAN 4/6: TINH DYNAMIC THRESHOLD + KHOI TAO STREAMING
# ============================================================

print("\n[4] DANG TINH DYNAMIC THRESHOLD...")


# ============================================================
# 1. CALIBRATION CHO TRAFFIC
# Lay cac mau BENIGN dau tien trong luong demo de tinh nguong
# threshold = mean(MSE) + 3 * std(MSE)
# ============================================================

CALIBRATION_SIZE = 100


benign_indices = np.where(
    traffic_labels == "BENIGN"
)[0]


if len(benign_indices) == 0:
    raise ValueError(
        "Khong co mau BENIGN de tinh dynamic threshold Traffic"
    )


traffic_calib_indices = benign_indices[
    : min(CALIBRATION_SIZE, len(benign_indices))
]


X_traffic_calib = X_real_traffic[
    traffic_calib_indices
]


traffic_calib_pred = traffic_model.predict(
    X_traffic_calib,
    batch_size=512,
    verbose=0
)


traffic_calib_mse = np.mean(
    np.square(
        X_traffic_calib - traffic_calib_pred
    ),
    axis=1
)


threshold_traffic = (
    np.mean(traffic_calib_mse)
    +
    3 * np.std(traffic_calib_mse)
)


print("\n===== DYNAMIC THRESHOLD TRAFFIC =====")
print(f"So mau calibration : {len(X_traffic_calib)}")
print(f"MSE mean           : {np.mean(traffic_calib_mse):.8f}")
print(f"MSE std            : {np.std(traffic_calib_mse):.8f}")
print(f"MSE max            : {np.max(traffic_calib_mse):.8f}")
print(f"Traffic Threshold  : {threshold_traffic:.8f}")


# ============================================================
# 2. CALIBRATION CHO LOG
# Lay 100 sequence log dau tien de tinh nguong
# ============================================================

log_calib_size = min(
    CALIBRATION_SIZE,
    len(X_real_log)
)


X_log_calib = X_real_log[
    :log_calib_size
]


log_calib_pred = log_model.predict(
    X_log_calib,
    batch_size=128,
    verbose=0
)


log_calib_mse = np.mean(
    np.square(
        X_log_calib - log_calib_pred
    ),
    axis=(1, 2)
)


threshold_log = (
    np.mean(log_calib_mse)
    +
    3 * np.std(log_calib_mse)
)


print("\n===== DYNAMIC THRESHOLD LOG =====")
print(f"So sequence calibration : {len(X_log_calib)}")
print(f"MSE mean                : {np.mean(log_calib_mse):.8f}")
print(f"MSE std                 : {np.std(log_calib_mse):.8f}")
print(f"MSE max                 : {np.max(log_calib_mse):.8f}")
print(f"Log Threshold           : {threshold_log:.8f}")


# ============================================================
# 3. KHOI TAO LAI QUEUE
# ============================================================

traffic_queue = queue.Queue(
    maxsize=500
)

log_queue = queue.Queue(
    maxsize=500
)


# ============================================================
# 4. EVENT DIEU KHIEN THREAD
# ============================================================

stop_event = threading.Event()

traffic_done_event = threading.Event()

log_done_event = threading.Event()


# ============================================================
# 5. BIEN THONG KE REALTIME
# ============================================================

stats = {
    "traffic_total": 0,
    "log_total": 0,

    "traffic_alert": 0,
    "log_alert": 0,

    "traffic_attack_total": 0,
    "traffic_attack_detected": 0,

    "traffic_false_positive": 0,

    "latency_list": [],
    "ram_list": [],

    "start_time": None,
    "end_time": None
}


print("\n[OK] Da khoi tao Queue, Event va bien thong ke.")


# ============================================================
# 6. GHI THONG TIN THRESHOLD VAO FILE LOG
# ============================================================

log_file.write("====================================================\n")
log_file.write("SYSTEM START - DYNAMIC THRESHOLD CONFIGURATION\n")
log_file.write("====================================================\n")

log_file.write(
    f"Traffic Threshold: {threshold_traffic:.8f}\n"
)

log_file.write(
    f"Log Threshold    : {threshold_log:.8f}\n"
)

log_file.write(
    f"Traffic Calibration Samples: {len(X_traffic_calib)}\n"
)

log_file.write(
    f"Log Calibration Sequences : {len(X_log_calib)}\n"
)

log_file.write("====================================================\n\n")

log_file.flush()


print("\n[OK] Dynamic Threshold da san sang cho Streaming Realtime.")

# ============================================================
# PHAN 5/6: BA THREAD STREAMING REALTIME
# ============================================================

print("\n[5] KHOI TAO CAC THREAD STREAMING...")


# ============================================================
# CAU HINH HIEN THI DEMO
# ============================================================

TRAFFIC_SLEEP = 0.03      # Toc do stream traffic
LOG_SLEEP = 0.04          # Toc do stream log
DISPLAY_EVERY = 15        # In man hinh moi 15 mau


# Mau console
RED = "\033[91m"
GREEN = "\033[92m"
YELLOW = "\033[93m"
RESET = "\033[0m"


# ============================================================
# THREAD 1: LOG INGESTION
# ============================================================

def log_ingestion_stream():
    """
    Thread 1:
    Doc tung sequence HDFS Log va day vao log_queue.
    Moi phan tu co shape (1, 10, 4).
    """

    print("[THREAD-LOG] Bat dau stream HDFS Log...")

    for idx, log_seq in enumerate(X_real_log):

        if stop_event.is_set():
            break

        log_queue.put(
            (
                idx,
                log_seq.reshape(1, TIMESTEPS, LOG_FEATURE_DIM)
            )
        )

        time.sleep(LOG_SLEEP)

    log_done_event.set()

    print("[THREAD-LOG] Da stream het HDFS Log.")


# ============================================================
# THREAD 2: PACKET ANALYSIS / TRAFFIC STREAM
# ============================================================

def packet_analysis_stream():
    """
    Thread 2:
    Doc tung flow traffic va day vao traffic_queue.
    Moi phan tu co shape (1, 47).
    Kem theo label that de thong ke demo.
    """

    print("[THREAD-TRAFFIC] Bat dau stream Network Traffic...")

    for idx, packet in enumerate(X_real_traffic):

        if stop_event.is_set():
            break

        label = traffic_labels[idx]

        traffic_queue.put(
            (
                idx,
                packet.reshape(1, len(TRAFFIC_FEATURES)),
                label
            )
        )

        time.sleep(TRAFFIC_SLEEP)

    traffic_done_event.set()

    print("[THREAD-TRAFFIC] Da stream het Network Traffic.")


# ============================================================
# THREAD 3: HYBRID MODEL INFERENCE
# ============================================================

def hybrid_model_inference():
    """
    Thread 3:
    Lay du lieu tu traffic_queue va log_queue.
    Chay:
    - Deep Autoencoder cho traffic
    - LSTM Autoencoder cho log

    Sau do:
    - Tinh Reconstruction Error
    - So sanh voi Dynamic Threshold
    - Do Latency
    - Do RAM
    - Ghi log
    - Cap nhat thong ke
    """

    print("[THREAD-AI] AI bat dau giam sat realtime...\n")

    stats["start_time"] = time.time()

    count = 0

    while True:

        # Neu 2 producer da xong va queue da rong thi ket thuc inference
        if (
            traffic_done_event.is_set()
            and log_done_event.is_set()
            and traffic_queue.empty()
            and log_queue.empty()
        ):
            break

        # Cho den khi ca 2 queue deu co du lieu
        if traffic_queue.empty() or log_queue.empty():
            time.sleep(0.01)
            continue

        # Lay 1 mau traffic va 1 sequence log
        traffic_idx, current_packet, current_label = traffic_queue.get()
        log_idx, current_log = log_queue.get()

        start_time = time.time()

        # ====================================================
        # AI INFERENCE
        # ====================================================

        pred_traffic = traffic_model(
            current_packet,
            training=False
        ).numpy()

        pred_log = log_model(
            current_log,
            training=False
        ).numpy()


        # Reconstruction Error
        error_traffic = float(
            np.mean(
                np.square(
                    current_packet - pred_traffic
                )
            )
        )

        error_log = float(
            np.mean(
                np.square(
                    current_log - pred_log
                )
            )
        )


        # So sanh threshold dong
        traffic_is_anomaly = (
            error_traffic > threshold_traffic
        )

        log_is_anomaly = (
            error_log > threshold_log
        )


        # Latency + RAM
        latency_ms = (
            time.time() - start_time
        ) * 1000

        ram_mb = (
            psutil.Process()
            .memory_info()
            .rss
            / (1024 * 1024)
        )


        # ====================================================
        # CAP NHAT THONG KE
        # ====================================================

        count += 1

        stats["traffic_total"] += 1
        stats["log_total"] += 1

        stats["latency_list"].append(
            latency_ms
        )

        stats["ram_list"].append(
            ram_mb
        )


        if traffic_is_anomaly:
            stats["traffic_alert"] += 1

        if log_is_anomaly:
            stats["log_alert"] += 1


        # Danh gia theo label that cua traffic demo
        is_attack = (
            current_label != "BENIGN"
        )

        if is_attack:
            stats["traffic_attack_total"] += 1

            if traffic_is_anomaly:
                stats["traffic_attack_detected"] += 1

        else:
            if traffic_is_anomaly:
                stats["traffic_false_positive"] += 1


        # ====================================================
        # HIEN THI CONSOLE
        # ====================================================

        traffic_status_clean = (
            "!!! CANH BAO: ANOMALY !!!"
            if traffic_is_anomaly
            else "An toan"
        )

        log_status_clean = (
            "!!! CANH BAO: ANOMALY !!!"
            if log_is_anomaly
            else "An toan"
        )

        traffic_status_color = (
            f"{RED}{traffic_status_clean}{RESET}"
            if traffic_is_anomaly
            else f"{GREEN}{traffic_status_clean}{RESET}"
        )

        log_status_color = (
            f"{RED}{log_status_clean}{RESET}"
            if log_is_anomaly
            else f"{GREEN}{log_status_clean}{RESET}"
        )


        # In ra man hinh moi DISPLAY_EVERY mau
        # hoac khi co canh bao bat thuong
        if (
            count % DISPLAY_EVERY == 0
            or traffic_is_anomaly
            or log_is_anomaly
        ):

            print(
                f"================ [GIAM SAT REALTIME #{count}] ================"
            )

            print(
                f" -> Traffic Label : {current_label}"
            )

            print(
                f" -> Traffic MSE   : {error_traffic:.8f} | "
                f"{traffic_status_color}"
            )

            print(
                f" -> Sys-Log MSE   : {error_log:.8f}     | "
                f"{log_status_color}"
            )

            print(
                f" -> Hieu nang     : Latency {latency_ms:.2f} ms | "
                f"RAM {ram_mb:.2f} MB"
            )

            print(
                "==============================================================="
            )


        # ====================================================
        # GHI FILE LOG SACH, KHONG MAU
        # ====================================================

        log_file.write(
            f"#{count} | "
            f"Label={current_label} | "
            f"Traffic_MSE={error_traffic:.8f} | "
            f"Traffic_Status={traffic_status_clean} | "
            f"Log_MSE={error_log:.8f} | "
            f"Log_Status={log_status_clean} | "
            f"Latency_ms={latency_ms:.2f} | "
            f"RAM_MB={ram_mb:.2f}\n"
        )

        log_file.flush()


    stats["end_time"] = time.time()

    print("\n[THREAD-AI] Da xu ly het du lieu realtime.")


    # ============================================================
# PHAN 6/6: KHOI DONG HE THONG VA IN BAO CAO TONG KET
# ============================================================

print("\n[6] KHOI DONG HE THONG STREAMING REALTIME...")


# ============================================================
# TAO THREAD
# ============================================================

thread_log = threading.Thread(
    target=log_ingestion_stream,
    name="LogIngestionThread"
)

thread_traffic = threading.Thread(
    target=packet_analysis_stream,
    name="PacketAnalysisThread"
)

thread_ai = threading.Thread(
    target=hybrid_model_inference,
    name="ModelInferenceThread"
)


# ============================================================
# START THREAD
# ============================================================

thread_log.start()
thread_traffic.start()
thread_ai.start()


# ============================================================
# DOI CAC THREAD KET THUC
# ============================================================

try:

    thread_log.join()
    thread_traffic.join()
    thread_ai.join()

except KeyboardInterrupt:

    print("\n[THONG BAO] Nguoi dung dung he thong bang Ctrl+C")

    stop_event.set()

    thread_log.join(timeout=2)
    thread_traffic.join(timeout=2)
    thread_ai.join(timeout=2)


# ============================================================
# TINH TOAN BAO CAO CUOI
# ============================================================

total_runtime = 0.0

if stats["start_time"] is not None and stats["end_time"] is not None:
    total_runtime = stats["end_time"] - stats["start_time"]


avg_latency = 0.0

if len(stats["latency_list"]) > 0:
    avg_latency = float(
        np.mean(stats["latency_list"])
    )


max_latency = 0.0

if len(stats["latency_list"]) > 0:
    max_latency = float(
        np.max(stats["latency_list"])
    )


avg_ram = 0.0

if len(stats["ram_list"]) > 0:
    avg_ram = float(
        np.mean(stats["ram_list"])
    )


peak_ram = 0.0

if len(stats["ram_list"]) > 0:
    peak_ram = float(
        np.max(stats["ram_list"])
    )


traffic_anomaly_rate = 0.0

if stats["traffic_total"] > 0:
    traffic_anomaly_rate = (
        stats["traffic_alert"]
        / stats["traffic_total"]
        * 100
    )


log_anomaly_rate = 0.0

if stats["log_total"] > 0:
    log_anomaly_rate = (
        stats["log_alert"]
        / stats["log_total"]
        * 100
    )


traffic_detection_rate = 0.0

if stats["traffic_attack_total"] > 0:
    traffic_detection_rate = (
        stats["traffic_attack_detected"]
        / stats["traffic_attack_total"]
        * 100
    )


false_positive_rate = 0.0

benign_total = (
    stats["traffic_total"]
    - stats["traffic_attack_total"]
)

if benign_total > 0:
    false_positive_rate = (
        stats["traffic_false_positive"]
        / benign_total
        * 100
    )


# ============================================================
# IN BAO CAO CONSOLE
# ============================================================

print("\n====================================================")
print("              BAO CAO TONG KET HE THONG")
print("====================================================")

print("\n[1] TRAFFIC AUTOENCODER")
print(f"Tong so flow da xu ly        : {stats['traffic_total']}")
print(f"So flow bi canh bao anomaly  : {stats['traffic_alert']}")
print(f"Ty le anomaly Traffic        : {traffic_anomaly_rate:.2f}%")

print("\n[2] DANH GIA THEO LABEL DEMO")
print(f"So flow attack thuc te       : {stats['traffic_attack_total']}")
print(f"So attack bi phat hien       : {stats['traffic_attack_detected']}")
print(f"Detection Rate               : {traffic_detection_rate:.2f}%")
print(f"False Positive               : {stats['traffic_false_positive']}")
print(f"False Positive Rate          : {false_positive_rate:.2f}%")

print("\n[3] HDFS LOG LSTM AUTOENCODER")
print(f"Tong so log sequence xu ly   : {stats['log_total']}")
print(f"So log sequence anomaly      : {stats['log_alert']}")
print(f"Ty le anomaly Log            : {log_anomaly_rate:.2f}%")

print("\n[4] HIEU NANG REALTIME")
print(f"Thoi gian chay tong          : {total_runtime:.2f} giay")
print(f"Latency trung binh           : {avg_latency:.2f} ms")
print(f"Latency cao nhat             : {max_latency:.2f} ms")
print(f"RAM trung binh               : {avg_ram:.2f} MB")
print(f"RAM cao nhat                 : {peak_ram:.2f} MB")

print("\n[5] DYNAMIC THRESHOLD")
print(f"Traffic Threshold            : {threshold_traffic:.8f}")
print(f"Log Threshold                : {threshold_log:.8f}")

print("====================================================")
print("Log chi tiet da luu tai: system_alert_log.txt")
print("====================================================")


# ============================================================
# GHI BAO CAO CUOI VAO FILE LOG
# ============================================================

log_file.write("\n====================================================\n")
log_file.write("FINAL SYSTEM SUMMARY\n")
log_file.write("====================================================\n")

log_file.write("\n[TRAFFIC AUTOENCODER]\n")
log_file.write(f"Total Traffic Processed: {stats['traffic_total']}\n")
log_file.write(f"Traffic Alerts: {stats['traffic_alert']}\n")
log_file.write(f"Traffic Anomaly Rate: {traffic_anomaly_rate:.2f}%\n")

log_file.write("\n[DEMO LABEL EVALUATION]\n")
log_file.write(f"Actual Attack Flows: {stats['traffic_attack_total']}\n")
log_file.write(f"Detected Attack Flows: {stats['traffic_attack_detected']}\n")
log_file.write(f"Detection Rate: {traffic_detection_rate:.2f}%\n")
log_file.write(f"False Positive: {stats['traffic_false_positive']}\n")
log_file.write(f"False Positive Rate: {false_positive_rate:.2f}%\n")

log_file.write("\n[HDFS LOG LSTM AUTOENCODER]\n")
log_file.write(f"Total Log Sequences Processed: {stats['log_total']}\n")
log_file.write(f"Log Alerts: {stats['log_alert']}\n")
log_file.write(f"Log Anomaly Rate: {log_anomaly_rate:.2f}%\n")

log_file.write("\n[PERFORMANCE]\n")
log_file.write(f"Total Runtime: {total_runtime:.2f} seconds\n")
log_file.write(f"Average Latency: {avg_latency:.2f} ms\n")
log_file.write(f"Max Latency: {max_latency:.2f} ms\n")
log_file.write(f"Average RAM: {avg_ram:.2f} MB\n")
log_file.write(f"Peak RAM: {peak_ram:.2f} MB\n")

log_file.write("\n[DYNAMIC THRESHOLD]\n")
log_file.write(f"Traffic Threshold: {threshold_traffic:.8f}\n")
log_file.write(f"Log Threshold: {threshold_log:.8f}\n")

log_file.write("====================================================\n")

log_file.flush()
log_file.close()


print("\n[HOAN TAT] He thong da ket thuc an toan.")
# Out:
# ====================================================
# HE THONG GIAM SAT THOI GIAN THUC
# Deep Autoencoder + LSTM Autoencoder
# ====================================================
#
# [1] DANG NAP MODEL...
# [INFO] Dang nap lai ./models/deep_autoencoder_traffic.h5 voi che do tuong thich Keras...
# [INFO] Dang nap lai ./models/lstm_autoencoder_logs.h5 voi che do tuong thich Keras...
# [OK] Traffic Model Loaded
# [OK] Log Model Loaded
# [OK] Traffic Scaler Loaded
# [OK] Log Scaler Loaded
# [OK] Traffic Feature Count = 47
#
# [2] DANG DOC VA XU LY NETWORK TRAFFIC...
# c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.6.1 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# -> Phan bo label Traffic: {'DDoS': 1900, 'BENIGN': 100}
# -> [OK] Traffic stream shape: (2000, 47)
# -> [OK] So mau calibration BENIGN: 100
# -> [OK] So mau attack demo: 1900
# -> [OK] Traffic input dim hop le: 47
#
# [3] DANG DOC VA XU LY HDFS LOG...
# -> [OK] HDFS Log base shape: (200, 10, 4)
# -> [OK] HDFS Log stream shape: (2000, 10, 4)
# -> [OK] So sequence goc: 200
# -> [OK] Log input shape hop le: (10, 4)
#
# [4] DANG TINH DYNAMIC THRESHOLD...
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
#
# ===== DYNAMIC THRESHOLD TRAFFIC =====
# So mau calibration : 100
# MSE mean           : 0.00005563
# MSE std            : 0.00013136
# MSE max            : 0.00098020
# Traffic Threshold  : 0.00044971
# Exception in thread Thread-12 (hybrid_model_inference):
# Traceback (most recent call last):
#   File "c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\huuhu\AppData\Local\Temp\ipykernel_12396\1320418142.py", line 181, in hybrid_model_inference
#   File "c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\site-packages\keras\src\utils\traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\site-packages\keras\src\layers\input_spec.py", line 160, in assert_input_compatibility
#     raise ValueError(
# ValueError: Layer "functional_5" expects 1 input(s), but it received 3 input tensors. Inputs received: [1, array([[9.08740509e-07, 0.00000000e+00, 1.61290323e-02, 9.39319932e-04,
#         7.56191316e-05, 3.18809777e-03, 7.79220779e-02, 1.67389957e-02,
#         0.00000000e+00, 1.49283439e-03, 2.21402214e-02, 4.16088766e-03,
#         0.00000000e+00, 7.10269310e-03, 1.83485690e-02, 4.22319238e-06,
#         0.00000000e+00, 1.56380446e-06, 5.56864442e-05, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.21951220e-02,
#         9.17428182e-03, 1.65137615e-01, 7.79220779e-02, 1.41843972e-03,
#         6.85078601e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00138735e-02, 4.16088766e-03]]), 'BENIGN']
# Exception in thread Thread-9 (hybrid_model_inference):
# Traceback (most recent call last):
#   File "c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\huuhu\AppData\Local\Temp\ipykernel_12396\768315585.py", line 174, in hybrid_model_inference
#   File "c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\site-packages\keras\src\utils\traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\site-packages\keras\src\layers\input_spec.py", line 160, in assert_input_compatibility
#     raise ValueError(
# ValueError: Layer "functional_5" expects 1 input(s), but it received 3 input tensors. Inputs received: [3, array([[2.71772862e-07, 0.00000000e+00, 1.61290323e-02, 9.39319932e-04,
#         7.56191316e-05, 3.18809777e-03, 7.79220779e-02, 1.67389957e-02,
#         0.00000000e+00, 1.49283439e-03, 2.21402214e-02, 4.16088766e-03,
#         0.00000000e+00, 2.27703985e-02, 5.88234769e-02, 1.26761451e-06,
#         0.00000000e+00, 4.67679838e-07, 1.73700835e-05, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.21951220e-02,
#         2.94117352e-02, 5.29411765e-01, 7.79220779e-02, 1.41843972e-03,
#         6.85078601e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00138735e-02, 4.16088766e-03]]), 'BENIGN']
# ===== DYNAMIC THRESHOLD LOG =====
# So sequence calibration : 100
# MSE mean                : 0.01552960
# MSE std                 : 0.01316754
# MSE max                 : 0.06200939
# Log Threshold           : 0.05503221
#
# [OK] Da khoi tao Queue, Event va bien thong ke.
#
# [OK] Dynamic Threshold da san sang cho Streaming Realtime.
#
# [5] KHOI TAO CAC THREAD STREAMING...
#
# [6] KHOI DONG HE THONG STREAMING REALTIME...
# [THREAD-LOG] Bat dau stream HDFS Log...
# [THREAD-TRAFFIC] Bat dau stream Network Traffic...
# [THREAD-AI] AI bat dau giam sat realtime...
# Exception in thread Thread-18 (hybrid_model_inference):
# Traceback (most recent call last):
#   File "c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\huuhu\AppData\Local\Temp\ipykernel_12396\1978765266.py", line 184, in hybrid_model_inference
#   File "c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\site-packages\keras\src\utils\traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\site-packages\keras\src\layers\input_spec.py", line 160, in assert_input_compatibility
#     raise ValueError(
# ValueError: Layer "functional_5" expects 1 input(s), but it received 3 input tensors. Inputs received: [5, array([[8.66275999e-06, 1.96078431e-02, 0.00000000e+00, 1.87863986e-03,
#         0.00000000e+00, 3.18809777e-03, 7.79220779e-02, 1.67389957e-02,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 7.57527934e-04, 1.95689143e-03, 4.02024270e-05,
#         0.00000000e+00, 1.49072948e-05, 5.22124275e-04, 8.68180469e-06,
#         1.59516659e-05, 0.00000000e+00, 1.50184069e-05, 1.59516659e-05,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.45772595e-02, 0.00000000e+00,
#         1.95691683e-03, 0.00000000e+00, 7.79220779e-02, 1.41843972e-03,
#         6.85078601e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#         0.00000000e+00, 1.00138735e-02, 0.00000000e+00]]), 'BENIGN']
# Exception in thread Thread-6 (hybrid_model_inference):
# Traceback (most recent call last):
#   File "c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\huuhu\AppData\Local\Temp\ipykernel_12396\1083855199.py", line 174, in hybrid_model_inference
#   File "c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\site-packages\keras\src\utils\traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "c:\Users\huuhu\miniconda3\envs\streaming_ai\lib\site-packages\keras\src\layers\input_spec.py", line 160, in assert_input_compatibility
#     raise ValueError(
# ValueError: Layer "functional_5" expects 1 input(s), but it received 3 input tensors. Inputs received: [7, array([[3.39716078e-07, 0.00000000e+00, 1.61290323e-02, 9.39319932e-04,
#         7.56191316e-05, 3.18809777e-03, 7.79220779e-02, 1.67389957e-02,
#         0.00000000e+00, 1.49283439e-03, 2.21402214e-02, 4.16088766e-03,
#         0.00000000e+00, 1.84331797e-02, 4.76189944e-02, 1.58287615e-06,
#         0.00000000e+00, 5.84599797e-07, 2.14571620e-05, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.21951220e-02,
#         2.38094941e-02, 4.28571429e-01, 7.79220779e-02, 1.41843972e-03,
#         6.85078601e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#         0.00000000e+00, 1.00138735e-02, 4.16088766e-03]]), 'BENIGN']
# ================ [GIAM SAT REALTIME #15] ================
#  -> Traffic Label : BENIGN
#  -> Traffic MSE   : 0.00000208 | An toan
#  -> Sys-Log MSE   : 0.00871502     | An toan
#  -> Hieu nang     : Latency 75.77 ms | RAM 612.75 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #30] ================
#  -> Traffic Label : BENIGN
#  -> Traffic MSE   : 0.00003851 | An toan
#  -> Sys-Log MSE   : 0.02638415     | An toan
#  -> Hieu nang     : Latency 81.79 ms | RAM 612.81 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #45] ================
#  -> Traffic Label : BENIGN
#  -> Traffic MSE   : 0.00001236 | An toan
#  -> Sys-Log MSE   : 0.00076771     | An toan
#  -> Hieu nang     : Latency 70.85 ms | RAM 612.81 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #60] ================
#  -> Traffic Label : BENIGN
#  -> Traffic MSE   : 0.00001269 | An toan
#  -> Sys-Log MSE   : 0.00835814     | An toan
#  -> Hieu nang     : Latency 67.82 ms | RAM 612.81 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #66] ================
#  -> Traffic Label : BENIGN
#  -> Traffic MSE   : 0.00001309 | An toan
#  -> Sys-Log MSE   : 0.06200938     | !!! CANH BAO: ANOMALY !!!
#  -> Hieu nang     : Latency 67.85 ms | RAM 612.81 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #75] ================
#  -> Traffic Label : BENIGN
#  -> Traffic MSE   : 0.00001023 | An toan
#  -> Sys-Log MSE   : 0.03859945     | An toan
#  -> Hieu nang     : Latency 72.80 ms | RAM 612.81 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #84] ================
#  -> Traffic Label : BENIGN
#  -> Traffic MSE   : 0.00098020 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00076780     | An toan
#  -> Hieu nang     : Latency 68.78 ms | RAM 612.81 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #86] ================
#  -> Traffic Label : BENIGN
#  -> Traffic MSE   : 0.00078026 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01614953     | An toan
#  -> Hieu nang     : Latency 64.83 ms | RAM 612.81 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #90] ================
#  -> Traffic Label : BENIGN
#  -> Traffic MSE   : 0.00002231 | An toan
#  -> Sys-Log MSE   : 0.00553216     | An toan
#  -> Hieu nang     : Latency 65.82 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #97] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00064264 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00399879     | An toan
#  -> Hieu nang     : Latency 68.78 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #99] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062700 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02883574     | An toan
#  -> Hieu nang     : Latency 64.83 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #100] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07881597 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01588280     | An toan
#  -> Hieu nang     : Latency 61.87 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #101] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00058526 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00677119     | An toan
#  -> Hieu nang     : Latency 64.83 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #102] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07925320 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01759771     | An toan
#  -> Hieu nang     : Latency 59.87 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #103] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00056089 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02394988     | An toan
#  -> Hieu nang     : Latency 66.79 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #104] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07875732 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01556328     | An toan
#  -> Hieu nang     : Latency 70.81 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #105] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00059971 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00887881     | An toan
#  -> Hieu nang     : Latency 77.79 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #106] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07849502 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.04998665     | An toan
#  -> Hieu nang     : Latency 65.84 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #107] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00058743 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01637619     | An toan
#  -> Hieu nang     : Latency 68.80 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #108] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.08037753 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.03300900     | An toan
#  -> Hieu nang     : Latency 72.81 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #109] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00065067 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.04614692     | An toan
#  -> Hieu nang     : Latency 67.83 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #110] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07796287 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00075178     | An toan
#  -> Hieu nang     : Latency 67.82 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #111] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00065204 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00075178     | An toan
#  -> Hieu nang     : Latency 67.82 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #112] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07794892 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02339684     | An toan
#  -> Hieu nang     : Latency 69.81 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #113] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054212 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00076779     | An toan
#  -> Hieu nang     : Latency 72.81 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #115] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00501713 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.03765728     | An toan
#  -> Hieu nang     : Latency 67.79 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #117] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00518412 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01081539     | An toan
#  -> Hieu nang     : Latency 70.84 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #119] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00564986 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02269864     | An toan
#  -> Hieu nang     : Latency 64.79 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #120] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00012156 | An toan
#  -> Sys-Log MSE   : 0.01958674     | An toan
#  -> Hieu nang     : Latency 62.86 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #121] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00679002 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01084702     | An toan
#  -> Hieu nang     : Latency 63.80 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #123] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00527098 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00736948     | An toan
#  -> Hieu nang     : Latency 74.81 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #125] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00884290 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01459231     | An toan
#  -> Hieu nang     : Latency 62.80 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #127] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00058650 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00972776     | An toan
#  -> Hieu nang     : Latency 65.79 ms | RAM 612.82 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #129] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00069927 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00735398     | An toan
#  -> Hieu nang     : Latency 65.82 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #131] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00065077 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02232435     | An toan
#  -> Hieu nang     : Latency 74.83 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #133] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00056480 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00075349     | An toan
#  -> Hieu nang     : Latency 68.85 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #135] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00053561 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02025291     | An toan
#  -> Hieu nang     : Latency 70.79 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #137] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00052818 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01253271     | An toan
#  -> Hieu nang     : Latency 67.79 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #139] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00053508 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02382194     | An toan
#  -> Hieu nang     : Latency 73.77 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #141] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00058279 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.03059612     | An toan
#  -> Hieu nang     : Latency 63.79 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #143] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00106570 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00346643     | An toan
#  -> Hieu nang     : Latency 65.82 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #145] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00058731 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.03019378     | An toan
#  -> Hieu nang     : Latency 66.79 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #147] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00058660 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01562658     | An toan
#  -> Hieu nang     : Latency 69.81 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #149] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00069933 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.05005419     | An toan
#  -> Hieu nang     : Latency 60.84 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #150] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00020580 | An toan
#  -> Sys-Log MSE   : 0.01914712     | An toan
#  -> Hieu nang     : Latency 61.83 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #151] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00065081 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.04755260     | An toan
#  -> Hieu nang     : Latency 62.83 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #153] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00065211 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00075147     | An toan
#  -> Hieu nang     : Latency 62.83 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #155] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00056093 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00996853     | An toan
#  -> Hieu nang     : Latency 64.82 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #157] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00053056 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.03332669     | An toan
#  -> Hieu nang     : Latency 69.81 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #159] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00052833 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02836851     | An toan
#  -> Hieu nang     : Latency 68.82 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #161] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00058771 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02413303     | An toan
#  -> Hieu nang     : Latency 69.81 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #163] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00069966 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01856474     | An toan
#  -> Hieu nang     : Latency 71.81 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #165] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00069968 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00717557     | An toan
#  -> Hieu nang     : Latency 66.79 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #167] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00055828 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.04309601     | An toan
#  -> Hieu nang     : Latency 69.81 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #169] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00055747 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.03338444     | An toan
#  -> Hieu nang     : Latency 61.83 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #171] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00057643 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00210657     | An toan
#  -> Hieu nang     : Latency 63.80 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #173] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00057658 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01953429     | An toan
#  -> Hieu nang     : Latency 66.79 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #175] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060475 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02859106     | An toan
#  -> Hieu nang     : Latency 72.77 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #177] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062765 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02084551     | An toan
#  -> Hieu nang     : Latency 68.82 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #180] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054749 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01882223     | An toan
#  -> Hieu nang     : Latency 62.83 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #182] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060129 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00075178     | An toan
#  -> Hieu nang     : Latency 62.83 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #184] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060702 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00076780     | An toan
#  -> Hieu nang     : Latency 68.81 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #186] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060719 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02741549     | An toan
#  -> Hieu nang     : Latency 66.80 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #188] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062407 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02160909     | An toan
#  -> Hieu nang     : Latency 76.79 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #190] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062398 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01541320     | An toan
#  -> Hieu nang     : Latency 68.82 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #192] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062453 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00574296     | An toan
#  -> Hieu nang     : Latency 68.82 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #194] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062441 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02024644     | An toan
#  -> Hieu nang     : Latency 74.80 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #195] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00019837 | An toan
#  -> Sys-Log MSE   : 0.02378128     | An toan
#  -> Hieu nang     : Latency 69.81 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #196] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062445 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00754264     | An toan
#  -> Hieu nang     : Latency 67.82 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #198] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00057016 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02093551     | An toan
#  -> Hieu nang     : Latency 66.82 ms | RAM 612.88 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #200] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054755 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01839629     | An toan
#  -> Hieu nang     : Latency 61.83 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #202] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054396 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00860563     | An toan
#  -> Hieu nang     : Latency 62.80 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #204] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054684 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01953218     | An toan
#  -> Hieu nang     : Latency 72.78 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #206] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054399 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01820855     | An toan
#  -> Hieu nang     : Latency 66.82 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #208] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054704 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01006713     | An toan
#  -> Hieu nang     : Latency 82.74 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #210] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054683 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01190009     | An toan
#  -> Hieu nang     : Latency 71.78 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #212] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054412 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00705569     | An toan
#  -> Hieu nang     : Latency 77.82 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #214] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054427 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01707144     | An toan
#  -> Hieu nang     : Latency 71.83 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #216] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054209 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02212427     | An toan
#  -> Hieu nang     : Latency 74.80 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #218] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00057450 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00321271     | An toan
#  -> Hieu nang     : Latency 66.82 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #220] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060748 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01249375     | An toan
#  -> Hieu nang     : Latency 68.82 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #222] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060732 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00986625     | An toan
#  -> Hieu nang     : Latency 70.82 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #224] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062446 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00504537     | An toan
#  -> Hieu nang     : Latency 74.80 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #225] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00021372 | An toan
#  -> Sys-Log MSE   : 0.01497127     | An toan
#  -> Hieu nang     : Latency 62.88 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #226] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060834 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.04671634     | An toan
#  -> Hieu nang     : Latency 62.83 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #228] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062559 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02752626     | An toan
#  -> Hieu nang     : Latency 65.82 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #230] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060842 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02638415     | An toan
#  -> Hieu nang     : Latency 71.84 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #232] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060839 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.05470346     | An toan
#  -> Hieu nang     : Latency 69.81 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #234] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062525 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00075391     | An toan
#  -> Hieu nang     : Latency 65.82 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #236] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00057846 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00075268     | An toan
#  -> Hieu nang     : Latency 75.80 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #238] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00053764 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00075268     | An toan
#  -> Hieu nang     : Latency 67.82 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #239] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00053097 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00399678     | An toan
#  -> Hieu nang     : Latency 66.87 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #240] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00021411 | An toan
#  -> Sys-Log MSE   : 0.00715598     | An toan
#  -> Hieu nang     : Latency 66.78 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #241] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054374 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00256695     | An toan
#  -> Hieu nang     : Latency 61.83 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #243] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054011 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00076781     | An toan
#  -> Hieu nang     : Latency 61.84 ms | RAM 612.89 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #245] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054019 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00076771     | An toan
#  -> Hieu nang     : Latency 66.79 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #247] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00052966 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01949771     | An toan
#  -> Hieu nang     : Latency 64.79 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #249] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054295 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01679343     | An toan
#  -> Hieu nang     : Latency 65.85 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #251] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054357 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01470754     | An toan
#  -> Hieu nang     : Latency 59.80 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #253] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00064801 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02227159     | An toan
#  -> Hieu nang     : Latency 64.86 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #255] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00073566 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00795505     | An toan
#  -> Hieu nang     : Latency 60.84 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #257] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00088452 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01574871     | An toan
#  -> Hieu nang     : Latency 81.78 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #259] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060127 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00612788     | An toan
#  -> Hieu nang     : Latency 66.82 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #261] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060102 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02228579     | An toan
#  -> Hieu nang     : Latency 69.81 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #263] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060381 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01964664     | An toan
#  -> Hieu nang     : Latency 69.81 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #265] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060289 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.03145392     | An toan
#  -> Hieu nang     : Latency 66.85 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #266] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00024055 | An toan
#  -> Sys-Log MSE   : 0.06200938     | !!! CANH BAO: ANOMALY !!!
#  -> Hieu nang     : Latency 65.82 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #267] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060702 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.03723142     | An toan
#  -> Hieu nang     : Latency 64.83 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #269] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060702 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01967514     | An toan
#  -> Hieu nang     : Latency 62.83 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #270] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00024242 | An toan
#  -> Sys-Log MSE   : 0.00755861     | An toan
#  -> Hieu nang     : Latency 75.80 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #271] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062386 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00553430     | An toan
#  -> Hieu nang     : Latency 60.84 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #273] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062375 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00854502     | An toan
#  -> Hieu nang     : Latency 69.81 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #275] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062354 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.03859945     | An toan
#  -> Hieu nang     : Latency 70.83 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #277] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00057453 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.03579981     | An toan
#  -> Hieu nang     : Latency 67.82 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #279] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054820 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00075208     | An toan
#  -> Hieu nang     : Latency 64.86 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #281] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00055181 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02326727     | An toan
#  -> Hieu nang     : Latency 63.80 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #283] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054810 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00076780     | An toan
#  -> Hieu nang     : Latency 61.80 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #285] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054775 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00076771     | An toan
#  -> Hieu nang     : Latency 66.79 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #287] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00055645 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02955813     | An toan
#  -> Hieu nang     : Latency 66.79 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #289] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054504 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00693457     | An toan
#  -> Hieu nang     : Latency 63.83 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #291] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054536 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01087680     | An toan
#  -> Hieu nang     : Latency 58.81 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #293] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054527 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01716448     | An toan
#  -> Hieu nang     : Latency 62.80 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #295] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054549 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00425758     | An toan
#  -> Hieu nang     : Latency 59.84 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #297] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060153 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00399879     | An toan
#  -> Hieu nang     : Latency 61.87 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #299] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060251 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02883574     | An toan
#  -> Hieu nang     : Latency 59.84 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #300] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00028615 | An toan
#  -> Sys-Log MSE   : 0.01588280     | An toan
#  -> Hieu nang     : Latency 60.84 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #301] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060249 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00677119     | An toan
#  -> Hieu nang     : Latency 62.80 ms | RAM 612.95 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #303] ================
#  -> Traffic Label : DDoS
# ...
# ===============================================================
# ================ [GIAM SAT REALTIME #1949] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07555159 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.05005419     | An toan
#  -> Hieu nang     : Latency 59.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1950] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062031 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01914712     | An toan
#  -> Hieu nang     : Latency 58.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1951] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07629877 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.04755260     | An toan
#  -> Hieu nang     : Latency 62.83 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1952] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060903 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01618077     | An toan
#  -> Hieu nang     : Latency 60.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1953] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07628973 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00075147     | An toan
#  -> Hieu nang     : Latency 59.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1954] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00057937 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00433141     | An toan
#  -> Hieu nang     : Latency 59.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1955] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07593178 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00996853     | An toan
#  -> Hieu nang     : Latency 64.80 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1956] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054872 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01214465     | An toan
#  -> Hieu nang     : Latency 61.87 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1957] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07472858 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.03332669     | An toan
#  -> Hieu nang     : Latency 58.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1958] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054873 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.05250933     | An toan
#  -> Hieu nang     : Latency 59.81 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1959] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07475081 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02836851     | An toan
#  -> Hieu nang     : Latency 64.83 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1960] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00056664 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00971522     | An toan
#  -> Hieu nang     : Latency 59.81 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1961] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07551665 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02413303     | An toan
#  -> Hieu nang     : Latency 62.83 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1962] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054910 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.04497254     | An toan
#  -> Hieu nang     : Latency 63.86 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1963] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07399758 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01856474     | An toan
#  -> Hieu nang     : Latency 62.80 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1964] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00056713 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.03127783     | An toan
#  -> Hieu nang     : Latency 61.87 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1965] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07474093 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00717557     | An toan
#  -> Hieu nang     : Latency 58.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1966] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00055286 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01265725     | An toan
#  -> Hieu nang     : Latency 60.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1967] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07399610 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.04309601     | An toan
#  -> Hieu nang     : Latency 62.83 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1968] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054832 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00075208     | An toan
#  -> Hieu nang     : Latency 59.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1969] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07599700 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.03338444     | An toan
#  -> Hieu nang     : Latency 58.81 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1970] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07599548 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01610918     | An toan
#  -> Hieu nang     : Latency 58.87 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1971] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00055799 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00210657     | An toan
#  -> Hieu nang     : Latency 62.83 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1972] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07557828 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01066468     | An toan
#  -> Hieu nang     : Latency 60.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1973] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054360 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01953429     | An toan
#  -> Hieu nang     : Latency 61.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1974] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07650100 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02799375     | An toan
#  -> Hieu nang     : Latency 59.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1975] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00054355 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02859106     | An toan
#  -> Hieu nang     : Latency 64.79 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1976] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07599236 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02578184     | An toan
#  -> Hieu nang     : Latency 60.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1977] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060352 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02084551     | An toan
#  -> Hieu nang     : Latency 59.87 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1978] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07398310 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.04461720     | An toan
#  -> Hieu nang     : Latency 59.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1979] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00065544 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.03754035     | An toan
#  -> Hieu nang     : Latency 62.83 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1980] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07398196 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01882223     | An toan
#  -> Hieu nang     : Latency 59.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1981] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060483 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00743889     | An toan
#  -> Hieu nang     : Latency 58.85 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1982] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07528915 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00075178     | An toan
#  -> Hieu nang     : Latency 59.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1983] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062199 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01527835     | An toan
#  -> Hieu nang     : Latency 64.83 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1984] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07397327 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00076780     | An toan
#  -> Hieu nang     : Latency 59.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1985] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00061665 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.03181117     | An toan
#  -> Hieu nang     : Latency 58.81 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1986] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07481744 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02741549     | An toan
#  -> Hieu nang     : Latency 61.86 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1987] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00061751 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02867759     | An toan
#  -> Hieu nang     : Latency 63.83 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1988] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07527501 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02160909     | An toan
#  -> Hieu nang     : Latency 62.80 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1989] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060866 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02663310     | An toan
#  -> Hieu nang     : Latency 60.87 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1990] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07524166 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01541320     | An toan
#  -> Hieu nang     : Latency 59.81 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1991] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062640 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02505377     | An toan
#  -> Hieu nang     : Latency 62.83 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1992] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07519708 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00574296     | An toan
#  -> Hieu nang     : Latency 60.87 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1993] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00060924 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.01019961     | An toan
#  -> Hieu nang     : Latency 60.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1994] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07518300 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02024644     | An toan
#  -> Hieu nang     : Latency 59.84 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1995] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.00062597 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.02378128     | An toan
#  -> Hieu nang     : Latency 63.81 ms | RAM 613.20 MB
# ===============================================================
# ================ [GIAM SAT REALTIME #1996] ================
#  -> Traffic Label : DDoS
#  -> Traffic MSE   : 0.07490295 | !!! CANH BAO: ANOMALY !!!
#  -> Sys-Log MSE   : 0.00754264     | An toan
#  -> Hieu nang     : Latency 59.85 ms | RAM 613.20 MB
# ===============================================================
#
# [THREAD-AI] Da xu ly het du lieu realtime.
#
# ====================================================
#               BAO CAO TONG KET HE THONG
# ====================================================
#
# [1] TRAFFIC AUTOENCODER
# Tong so flow da xu ly        : 1996
# So flow bi canh bao anomaly  : 1237
# Ty le anomaly Traffic        : 61.97%
#
# [2] DANH GIA THEO LABEL DEMO
# So flow attack thuc te       : 1900
# So attack bi phat hien       : 1235
# Detection Rate               : 65.00%
# False Positive               : 2
# False Positive Rate          : 2.08%
#
# [3] HDFS LOG LSTM AUTOENCODER
# Tong so log sequence xu ly   : 1996
# So log sequence anomaly      : 10
# Ty le anomaly Log            : 0.50%
#
# [4] HIEU NANG REALTIME
# Thoi gian chay tong          : 130.20 giay
# Latency trung binh           : 65.04 ms
# Latency cao nhat             : 220.48 ms
# RAM trung binh               : 613.08 MB
# RAM cao nhat                 : 613.20 MB
#
# [5] DYNAMIC THRESHOLD
# Traffic Threshold            : 0.00044971
# Log Threshold                : 0.05503221
# ====================================================
# Log chi tiet da luu tai: system_alert_log.txt
# ====================================================
#
# [HOAN TAT] He thong da ket thuc an toan.
